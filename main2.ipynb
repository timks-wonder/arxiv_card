# %%
# %matplotlib inline
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# 这行代码的作用是设置 matplotlib 绘图时使用的字体为黑体（SimHei），并将字体大小设置为 13。
# 在使用 matplotlib 绘图时，如果需要显示中文，通常需要设置合适的字体，否则中文可能会显示为乱码。
# 通过这行代码，可以确保绘图中的中文文本能够正确显示，并且保持一致的字体和大小。

import os,gc,re,warnings,sys
warnings.filterwarnings("ignore")

# %%
path = 'data/'

trn_click = pd.read_csv(path + 'train_click_log.csv')
item_df = pd.read_csv(path + 'articles.csv')
item_df = item_df.rename(columns={'article_id': 'click_article_id'})
item_emb_df = pd.read_csv(path + 'articles_emb.csv')
tst_click = pd.read_csv(path + 'testA_click_log.csv')

# %%
trn_click['rank'] = trn_click.groupby(['user_id'])['click_timestamp'].rank(ascending=False).astype(int)
tst_click['rank'] = tst_click.groupby(['user_id'])['click_timestamp'].rank(ascending=False).astype(int)

# %%
#计算用户点击文章的次数，并添加新的一列count
trn_click['click_cnts'] = trn_click.groupby(['user_id'])['click_timestamp'].transform('count')
tst_click['click_cnts'] = tst_click.groupby(['user_id'])['click_timestamp'].transform('count')

# %%
trn_click = trn_click.merge(item_df, how='left', on=['click_article_id'])
trn_click.head()
# Out:
#    user_id  click_article_id  click_timestamp  click_environment  \
# 0   199999            160417    1507029570190                  4
# 1   199999              5408    1507029571478                  4
# 2   199999             50823    1507029601478                  4
# 3   199998            157770    1507029532200                  4
# 4   199998             96613    1507029671831                  4
#
#    click_deviceGroup  click_os  click_country  click_region  \
# 0                  1        17              1            13
# 1                  1        17              1            13
# 2                  1        17              1            13
# 3                  1        17              1            25
# 4                  1        17              1            25
#
#    click_referrer_type  rank  click_cnts  category_id  created_at_ts  \
# 0                    1    11          11          281  1506942089000
# 1                    1    10          11            4  1506994257000
# 2                    1     9          11           99  1507013614000
# 3                    5    40          40          281  1506983935000
# 4                    5    39          40          209  1506938444000
#
#    words_count
# 0          173
# 1          118
# 2          213
# 3          201
# 4          185

# %%
trn_click.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1112623 entries, 0 to 1112622
# Data columns (total 14 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   user_id              1112623 non-null  int64
#  1   click_article_id     1112623 non-null  int64
#  2   click_timestamp      1112623 non-null  int64
#  3   click_environment    1112623 non-null  int64
#  4   click_deviceGroup    1112623 non-null  int64
#  5   click_os             1112623 non-null  int64
#  6   click_country        1112623 non-null  int64
#  7   click_region         1112623 non-null  int64
#  8   click_referrer_type  1112623 non-null  int64
#  9   rank                 1112623 non-null  int64
#  10  click_cnts           1112623 non-null  int64
#  11  category_id          1112623 non-null  int64
#  12  created_at_ts        1112623 non-null  int64
#  13  words_count          1112623 non-null  int64
# dtypes: int64(14)
# memory usage: 127.3 MB

# %%
trn_click.describe()
# Out:
#             user_id  click_article_id  click_timestamp  click_environment  \
# count  1.112623e+06      1.112623e+06     1.112623e+06       1.112623e+06
# mean   1.221198e+05      1.951541e+05     1.507588e+12       3.947786e+00
# std    5.540349e+04      9.292286e+04     3.363466e+08       3.276715e-01
# min    0.000000e+00      3.000000e+00     1.507030e+12       1.000000e+00
# 25%    7.934700e+04      1.239090e+05     1.507297e+12       4.000000e+00
# 50%    1.309670e+05      2.038900e+05     1.507596e+12       4.000000e+00
# 75%    1.704010e+05      2.777120e+05     1.507841e+12       4.000000e+00
# max    1.999990e+05      3.640460e+05     1.510603e+12       4.000000e+00
#
#        click_deviceGroup      click_os  click_country  click_region  \
# count       1.112623e+06  1.112623e+06   1.112623e+06  1.112623e+06
# mean        1.815981e+00  1.301976e+01   1.310776e+00  1.813587e+01
# std         1.035170e+00  6.967844e+00   1.618264e+00  7.105832e+00
# min         1.000000e+00  2.000000e+00   1.000000e+00  1.000000e+00
# 25%         1.000000e+00  2.000000e+00   1.000000e+00  1.300000e+01
# 50%         1.000000e+00  1.700000e+01   1.000000e+00  2.100000e+01
# 75%         3.000000e+00  1.700000e+01   1.000000e+00  2.500000e+01
# max         5.000000e+00  2.000000e+01   1.100000e+01  2.800000e+01
#
#        click_referrer_type          rank    click_cnts   category_id  \
# count         1.112623e+06  1.112623e+06  1.112623e+06  1.112623e+06
# mean          1.910063e+00  7.118518e+00  1.323704e+01  3.056176e+02
# std           1.220012e+00  1.016095e+01  1.631503e+01  1.155791e+02
# min           1.000000e+00  1.000000e+00  2.000000e+00  1.000000e+00
# 25%           1.000000e+00  2.000000e+00  4.000000e+00  2.500000e+02
# 50%           2.000000e+00  4.000000e+00  8.000000e+00  3.280000e+02
# 75%           2.000000e+00  8.000000e+00  1.600000e+01  4.100000e+02
# max           7.000000e+00  2.410000e+02  2.410000e+02  4.600000e+02
#
#        created_at_ts   words_count
# count   1.112623e+06  1.112623e+06
# mean    1.506598e+12  2.011981e+02
# std     8.343066e+09  5.223881e+01
# min     1.166573e+12  0.000000e+00
# 25%     1.507220e+12  1.700000e+02
# 50%     1.507553e+12  1.970000e+02
# 75%     1.507756e+12  2.280000e+02
# max     1.510666e+12  6.690000e+03

# %%
trn_click.user_id.nunique()
# Out:
# 200000

# %%
trn_click.groupby('user_id')['click_article_id'].count().min()
# Out:
# 2

# %%
plt.figure()
plt.figure(figsize=(15, 20))
i = 1
for col in ['click_article_id', 'click_timestamp', 'click_environment', 'click_deviceGroup', 'click_os', 'click_country', 
            'click_region', 'click_referrer_type', 'rank', 'click_cnts']:
            plot_envs = plt.subplot(5,2, i)
            i += 1
            v = trn_click[col].value_counts().reset_index()[:10]
            fig = sns.barplot(x=v['index'], y=v[col])
            for item in fig.get_xticklabels():
                item.set_rotation(90)
            plt.title(col)
plt.tight_layout()
plt.show()

# %%
trn_click['click_environment'].value_counts()
# Out:
# 4    1084627
# 2      25894
# 1       2102
# Name: click_environment, dtype: int64

# %%
trn_click['click_deviceGroup'].value_counts()
# Out:
# 1    678187
# 3    395558
# 4     38731
# 5       141
# 2         6
# Name: click_deviceGroup, dtype: int64

# %%
tst_click = tst_click.merge(item_df, how='left', on=['click_article_id'])
tst_click.head()
# Out:
#    user_id  click_article_id  click_timestamp  click_environment  \
# 0   249999            160974    1506959142820                  4
# 1   249999            160417    1506959172820                  4
# 2   249998            160974    1506959056066                  4
# 3   249998            202557    1506959086066                  4
# 4   249997            183665    1506959088613                  4
#
#    click_deviceGroup  click_os  click_country  click_region  \
# 0                  1        17              1            13
# 1                  1        17              1            13
# 2                  1        12              1            13
# 3                  1        12              1            13
# 4                  1        17              1            15
#
#    click_referrer_type  rank  click_cnts  category_id  created_at_ts  \
# 0                    2    19          19          281  1506912747000
# 1                    2    18          19          281  1506942089000
# 2                    2     5           5          281  1506912747000
# 3                    2     4           5          327  1506938401000
# 4                    5     7           7          301  1500895686000
#
#    words_count
# 0          259
# 1          173
# 2          259
# 3          219
# 4          256

# %%
tst_click.describe()
# Out:
#              user_id  click_article_id  click_timestamp  click_environment  \
# count  518010.000000     518010.000000     5.180100e+05      518010.000000
# mean   227342.428169     193803.792550     1.507387e+12           3.947300
# std     14613.907188      88279.388177     3.706127e+08           0.323916
# min    200000.000000        137.000000     1.506959e+12           1.000000
# 25%    214926.000000     128551.000000     1.507026e+12           4.000000
# 50%    229109.000000     199197.000000     1.507308e+12           4.000000
# 75%    240182.000000     272143.000000     1.507666e+12           4.000000
# max    249999.000000     364043.000000     1.508832e+12           4.000000
#
#        click_deviceGroup       click_os  click_country   click_region  \
# count      518010.000000  518010.000000  518010.000000  518010.000000
# mean            1.738285      13.628467       1.348209      18.250250
# std             1.020858       6.625564       1.703524       7.060798
# min             1.000000       2.000000       1.000000       1.000000
# 25%             1.000000      12.000000       1.000000      13.000000
# 50%             1.000000      17.000000       1.000000      21.000000
# 75%             3.000000      17.000000       1.000000      25.000000
# max             5.000000      20.000000      11.000000      28.000000
#
#        click_referrer_type           rank     click_cnts    category_id  \
# count        518010.000000  518010.000000  518010.000000  518010.000000
# mean              1.819614      15.521785      30.043586     305.324961
# std               1.082657      33.957702      56.868021     110.411513
# min               1.000000       1.000000       1.000000       1.000000
# 25%               1.000000       4.000000      10.000000     252.000000
# 50%               2.000000       8.000000      19.000000     323.000000
# 75%               2.000000      18.000000      35.000000     399.000000
# max               7.000000     938.000000     938.000000     460.000000
#
#        created_at_ts    words_count
# count   5.180100e+05  518010.000000
# mean    1.506883e+12     210.966331
# std     5.816668e+09      83.040065
# min     1.265812e+12       0.000000
# 25%     1.506970e+12     176.000000
# 50%     1.507249e+12     199.000000
# 75%     1.507630e+12     232.000000
# max     1.509949e+12    3082.000000

# %%
tst_click.user_id.nunique()
# Out:
# 50000

# %%
tst_click.groupby('user_id')['click_article_id'].count().min() # 注意测试集里面有只点击过一次文章的用户
# Out:
# 1

# %%
#新闻文章数据集浏览
item_df.head().append(item_df.tail())
# Out:
#         click_article_id  category_id  created_at_ts  words_count
# 0                      0            0  1513144419000          168
# 1                      1            1  1405341936000          189
# 2                      2            1  1408667706000          250
# 3                      3            1  1408468313000          230
# 4                      4            1  1407071171000          162
# 364042            364042          460  1434034118000          144
# 364043            364043          460  1434148472000          463
# 364044            364044          460  1457974279000          177
# 364045            364045          460  1515964737000          126
# 364046            364046          460  1505811330000          479

# %%
item_df['words_count'].value_counts()
# print(item_df['words_count'])
# Out:
# 176     3485
# 182     3480
# 179     3463
# 178     3458
# 174     3456
#         ...
# 556        1
# 625        1
# 2798       1
# 767        1
# 841        1
# Name: words_count, Length: 866, dtype: int64

# %%
print(item_df['category_id'].nunique())     # 461个文章主题
item_df['category_id'].hist()
# Out:
# 461
# <Axes: >

# %%
item_df.shape
# Out:
# (364047, 4)

# %%
item_emb_df.head()
# Out:
#    article_id     emb_0     emb_1     emb_2     emb_3     emb_4     emb_5  \
# 0           0 -0.161183 -0.957233 -0.137944  0.050855  0.830055  0.901365
# 1           1 -0.523216 -0.974058  0.738608  0.155234  0.626294  0.485297
# 2           2 -0.619619 -0.972960 -0.207360 -0.128861  0.044748 -0.387535
# 3           3 -0.740843 -0.975749  0.391698  0.641738 -0.268645  0.191745
# 4           4 -0.279052 -0.972315  0.685374  0.113056  0.238315  0.271913
#
#       emb_6     emb_7     emb_8  ...   emb_240   emb_241   emb_242   emb_243  \
# 0 -0.335148 -0.559561 -0.500603  ...  0.321248  0.313999  0.636412  0.169179
# 1 -0.715657 -0.897996 -0.359747  ... -0.487843  0.823124  0.412688 -0.338654
# 2 -0.730477 -0.066126 -0.754899  ...  0.454756  0.473184  0.377866 -0.863887
# 3 -0.825593 -0.710591 -0.040099  ...  0.271535  0.036040  0.480029 -0.763173
# 4 -0.568816  0.341194 -0.600554  ...  0.238286  0.809268  0.427521 -0.615932
#
#     emb_244   emb_245   emb_246   emb_247   emb_248   emb_249
# 0  0.540524 -0.813182  0.286870 -0.231686  0.597416  0.409623
# 1  0.320786  0.588643 -0.594137  0.182828  0.397090 -0.834364
# 2 -0.383365  0.137721 -0.810877 -0.447580  0.805932 -0.285284
# 3  0.022627  0.565165 -0.910286 -0.537838  0.243541 -0.885329
# 4 -0.503697  0.614450 -0.917760 -0.424061  0.185484 -0.580292
#
# [5 rows x 251 columns]

# %%
item_emb_df.shape
# Out:
# (364047, 251)

# %%
#####merge
user_click_merge = trn_click.append(tst_click)

# %%
#用户重复点击
user_click_count = user_click_merge.groupby(['user_id', 'click_article_id'])['click_timestamp'].agg({'count'}).reset_index()
user_click_count[:10]
# Out:
#    user_id  click_article_id  count
# 0        0             30760      1
# 1        0            157507      1
# 2        1             63746      1
# 3        1            289197      1
# 4        2             36162      1
# 5        2            168401      1
# 6        3             36162      1
# 7        3             50644      1
# 8        4             39894      1
# 9        4             42567      1

# %%
user_click_count[user_click_count['count']>7]
# Out:
#         user_id  click_article_id  count
# 311242    86295             74254     10
# 311243    86295             76268     10
# 393761   103237            205948     10
# 393763   103237            235689     10
# 576902   134850             69463     13

# %%
user_click_count['count'].unique()
# Out:
# array([ 1,  2,  4,  3,  6,  5, 10,  7, 13])

# %%
user_click_count.loc[:,'count'].value_counts()
# Out:
# 1     1605541
# 2       11621
# 3         422
# 4          77
# 5          26
# 6          12
# 10          4
# 7           3
# 13          1
# Name: count, dtype: int64

# %%
def plot_envs(df, cols, r, c):
    plt.figure()
    plt.figure(figsize=(10, 5))
    i = 1
    for col in cols:
        plt.subplot(r, c, i)
        i += 1
        v = df[col].value_counts().reset_index()
        fig = sns.barplot(x=v['index'], y=v[col])
        for item in fig.get_xticklabels():
            item.set_rotation(90)
        plt.title(col)
    plt.tight_layout()
    plt.show()

# %%
# 分析用户点击环境变化是否明显，这里随机采样10个用户分析这些用户的点击环境分布
sample_user_ids = np.random.choice(tst_click['user_id'].unique(), size=10, replace=False)
sample_users = user_click_merge[user_click_merge['user_id'].isin(sample_user_ids)]
cols = ['click_environment','click_deviceGroup', 'click_os', 'click_country', 'click_region','click_referrer_type']
for _, user_df in sample_users.groupby('user_id'):
    plot_envs(user_df, cols, 2, 3)

# %%
user_click_item_count = sorted(user_click_merge.groupby('user_id')['click_article_id'].count(), reverse=True)
plt.plot(user_click_item_count)

# %%
#点击次数在前50的用户
plt.plot(user_click_item_count[:50])

# %%
#点击次数排名在[25000:50000]之间
plt.plot(user_click_item_count[25000:50000])

# %%
item_click_count = sorted(user_click_merge.groupby('click_article_id')['user_id'].count(), reverse=True)
plt.plot(item_click_count)

# %%
plt.plot(item_click_count[:100])

# %%
plt.plot(item_click_count[:20])

# %%
plt.plot(item_click_count[3500:])

# %%
tmp = user_click_merge.sort_values('click_timestamp')
tmp['next_item'] = tmp.groupby(['user_id'])['click_article_id'].transform(lambda x:x.shift(-1))
union_item = tmp.groupby(['click_article_id','next_item'])['click_timestamp'].agg({'count'}).reset_index().sort_values('count', ascending=False)
union_item[['count']].describe()
# Out:
#                count
# count  433597.000000
# mean        3.184139
# std        18.851753
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max      2202.000000

# %%
#画个图直观地看一看
x = union_item['click_article_id']
y = union_item['count']
plt.scatter(x, y)

# %%
plt.plot(union_item['count'].values[40000:])

# %%
#不同类型的新闻出现的次数
plt.plot(user_click_merge['category_id'].value_counts().values)

# %%
#出现次数比较少的新闻类型, 有些新闻类型，基本上就出现过几次
plt.plot(user_click_merge['category_id'].value_counts().values[150:])

# %%
#新闻字数的描述性统计
user_click_merge['words_count'].describe()
# Out:
# count    1.630633e+06
# mean     2.043012e+02
# std      6.382198e+01
# min      0.000000e+00
# 25%      1.720000e+02
# 50%      1.970000e+02
# 75%      2.290000e+02
# max      6.690000e+03
# Name: words_count, dtype: float64

# %%
plt.plot(user_click_merge['words_count'].values)

# %%
plt.plot(sorted(user_click_merge.groupby('user_id')['category_id'].nunique(), reverse=True))

# %%
user_click_merge.groupby('user_id')['category_id'].nunique().reset_index().describe()
# Out:
#              user_id    category_id
# count  250000.000000  250000.000000
# mean   124999.500000       4.573188
# std     72168.927986       4.419800
# min         0.000000       1.000000
# 25%     62499.750000       2.000000
# 50%    124999.500000       3.000000
# 75%    187499.250000       6.000000
# max    249999.000000      95.000000

# %%
plt.plot(sorted(user_click_merge.groupby('user_id')['words_count'].mean(), reverse=True))

# %%
#挑出大多数人的区间仔细看看
plt.plot(sorted(user_click_merge.groupby('user_id')['words_count'].mean(), reverse=True)[1000:45000])

# %%
#更加详细的参数
user_click_merge.groupby('user_id')['words_count'].mean().reset_index().describe()
# Out:
#              user_id    words_count
# count  250000.000000  250000.000000
# mean   124999.500000     205.830189
# std     72168.927986      47.174030
# min         0.000000       8.000000
# 25%     62499.750000     187.500000
# 50%    124999.500000     202.000000
# 75%    187499.250000     217.750000
# max    249999.000000    3434.500000

# %%
#为了更好的可视化，这里把时间进行归一化操作
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()
user_click_merge['click_timestamp'] = mm.fit_transform(user_click_merge[['click_timestamp']])
user_click_merge['created_at_ts'] = mm.fit_transform(user_click_merge[['created_at_ts']])

user_click_merge = user_click_merge.sort_values('click_timestamp')

# %%
user_click_merge.head()
# Out:
#     user_id  click_article_id  click_timestamp  click_environment  \
# 18   249990            162300         0.000000                  4
# 2    249998            160974         0.000002                  4
# 30   249985            160974         0.000003                  4
# 50   249979            162300         0.000004                  4
# 25   249988            160974         0.000004                  4
#
#     click_deviceGroup  click_os  click_country  click_region  \
# 18                  3        20              1            25
# 2                   1        12              1            13
# 30                  1        17              1             8
# 50                  1        17              1            25
# 25                  1        17              1            21
#
#     click_referrer_type  rank  click_cnts  category_id  created_at_ts  \
# 18                    2     5           5          281       0.989186
# 2                     2     5           5          281       0.989092
# 30                    2     8           8          281       0.989092
# 50                    2     2           2          281       0.989186
# 25                    2    17          17          281       0.989092
#
#     words_count
# 18          193
# 2           259
# 30          259
# 50          193
# 25          259

# %%
def mean_diff_time_func(df, col):
    df = pd.DataFrame(df, columns={col})
    df['time_shift1'] = df[col].shift(1).fillna(0)
    df['diff_time'] = abs(df[col] - df['time_shift1'])
    return df['diff_time'].mean()

# %%
# 点击时间差的平均值
mean_diff_click_time = user_click_merge.groupby('user_id')['click_timestamp', 'created_at_ts'].apply(lambda x: mean_diff_time_func(x, 'click_timestamp'))

# %%
plt.plot(sorted(mean_diff_click_time.values, reverse=True))

# %%
# 前后点击文章的创建时间差的平均值
mean_diff_created_time = user_click_merge.groupby('user_id')['click_timestamp', 'created_at_ts'].apply(lambda x: mean_diff_time_func(x, 'created_at_ts'))

# %%
plt.plot(sorted(mean_diff_created_time.values, reverse=True))

# %%
user_click_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1630633 entries, 18 to 1091178
# Data columns (total 14 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   user_id              1630633 non-null  int64
#  1   click_article_id     1630633 non-null  int64
#  2   click_timestamp      1630633 non-null  float64
#  3   click_environment    1630633 non-null  int64
#  4   click_deviceGroup    1630633 non-null  int64
#  5   click_os             1630633 non-null  int64
#  6   click_country        1630633 non-null  int64
#  7   click_region         1630633 non-null  int64
#  8   click_referrer_type  1630633 non-null  int64
#  9   rank                 1630633 non-null  int64
#  10  click_cnts           1630633 non-null  int64
#  11  category_id          1630633 non-null  int64
#  12  created_at_ts        1630633 non-null  float64
#  13  words_count          1630633 non-null  int64
# dtypes: float64(2), int64(12)
# memory usage: 186.6 MB

# %%
from gensim.models import Word2Vec
import logging, pickle

def train_item_word2vec(click_df, embed_size=16, save_name='item_w2v_emb.pkl', split_char=' '):
    click_df = click_df.sort_values('click_timestamp')
    click_df['click_article_id'] = click_df['click_article_id'].astype(str)
    
    docs = click_df.groupby(['user_id'])['click_article_id'].apply(lambda x: list(x)).reset_index()
    docs = docs['click_article_id'].values.tolist()

    logging.basicConfig(format='%(asctime)s:%(levelname)s:%(message)s', level=logging.INFO)

    # 修正参数名 size -> vector_size，并修正拼写错误 wokers -> workers
    w2v = Word2Vec(docs, vector_size=16, sg=1, window=5, seed=2020, workers=24, min_count=1, epochs=50)
    
    item_w2v_emb_dict = {k: w2v.wv[k] for k in click_df['click_article_id']}
    
    return item_w2v_emb_dict

item_w2v_emb_dict = train_item_word2vec(user_click_merge)
# Out:
# 2025-03-31 17:49:41,569:INFO:collecting all words and their counts
# 2025-03-31 17:49:41,570:INFO:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-03-31 17:49:41,572:INFO:PROGRESS: at sentence #10000, processed 25727 words, keeping 3473 word types
# 2025-03-31 17:49:41,575:INFO:PROGRESS: at sentence #20000, processed 53883 words, keeping 5811 word types
# 2025-03-31 17:49:41,579:INFO:PROGRESS: at sentence #30000, processed 84881 words, keeping 7676 word types
# 2025-03-31 17:49:41,583:INFO:PROGRESS: at sentence #40000, processed 118390 words, keeping 9297 word types
# 2025-03-31 17:49:41,588:INFO:PROGRESS: at sentence #50000, processed 154179 words, keeping 10844 word types
# 2025-03-31 17:49:41,592:INFO:PROGRESS: at sentence #60000, processed 192350 words, keeping 12357 word types
# 2025-03-31 17:49:41,597:INFO:PROGRESS: at sentence #70000, processed 233685 words, keeping 13473 word types
# 2025-03-31 17:49:41,603:INFO:PROGRESS: at sentence #80000, processed 281335 words, keeping 14939 word types
# 2025-03-31 17:49:41,609:INFO:PROGRESS: at sentence #90000, processed 329973 words, keeping 16420 word types
# 2025-03-31 17:49:41,614:INFO:PROGRESS: at sentence #100000, processed 379428 words, keeping 17904 word types
# 2025-03-31 17:49:41,620:INFO:PROGRESS: at sentence #110000, processed 431464 words, keeping 18928 word types
# 2025-03-31 17:49:41,626:INFO:PROGRESS: at sentence #120000, processed 489655 words, keeping 20157 word types
# 2025-03-31 17:49:41,632:INFO:PROGRESS: at sentence #130000, processed 550375 words, keeping 21588 word types
# 2025-03-31 17:49:41,640:INFO:PROGRESS: at sentence #140000, processed 613031 words, keeping 22923 word types
# 2025-03-31 17:49:41,647:INFO:PROGRESS: at sentence #150000, processed 678645 words, keeping 24209 word types
# 2025-03-31 17:49:41,655:INFO:PROGRESS: at sentence #160000, processed 749559 words, keeping 25743 word types
# 2025-03-31 17:49:41,663:INFO:PROGRESS: at sentence #170000, processed 831064 words, keeping 27232 word types
# 2025-03-31 17:49:41,674:INFO:PROGRESS: at sentence #180000, processed 914233 words, keeping 28612 word types
# 2025-03-31 17:49:41,682:INFO:PROGRESS: at sentence #190000, processed 1004976 words, keeping 29699 word types
# 2025-03-31 17:49:41,696:INFO:PROGRESS: at sentence #200000, processed 1112623 words, keeping 31116 word types
# 2025-03-31 17:49:41,708:INFO:PROGRESS: at sentence #210000, processed 1200577 words, keeping 31798 word types
# 2025-03-31 17:49:41,719:INFO:PROGRESS: at sentence #220000, processed 1285942 words, keeping 32381 word types
# 2025-03-31 17:49:41,729:INFO:PROGRESS: at sentence #230000, processed 1380836 words, keeping 33131 word types
# 2025-03-31 17:49:41,741:INFO:PROGRESS: at sentence #240000, processed 1498710 words, keeping 34213 word types
# 2025-03-31 17:49:41,754:INFO:collected 35380 word types from a corpus of 1630633 raw words and 250000 sentences
# 2025-03-31 17:49:41,754:INFO:Creating a fresh vocabulary
# 2025-03-31 17:49:41,789:INFO:Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 35380 unique words (100.00% of original 35380, drops 0)', 'datetime': '2025-03-31T17:49:41.789667', 'gensim': '4.3.3', 'python': '3.10.16 (main, Dec 11 2024, 10:22:29) [Clang 14.0.6 ]', 'platform': 'macOS-15.3.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2025-03-31 17:49:41,790:INFO:Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 1630633 word corpus (100.00% of original 1630633, drops 0)', 'datetime': '2025-03-31T17:49:41.790065', 'gensim': '4.3.3', 'python': '3.10.16 (main, Dec 11 2024, 10:22:29) [Clang 14.0.6 ]', 'platform': 'macOS-15.3.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2025-03-31 17:49:41,837:INFO:deleting the raw counts dictionary of 35380 items
# 2025-03-31 17:49:41,838:INFO:sample=0.001 downsamples 73 most-common words
# 2025-03-31 17:49:41,838:INFO:Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1452855.7219737575 word corpus (89.1%% of prior 1630633)', 'datetime': '2025-03-31T17:49:41.838422', 'gensim': '4.3.3', 'python': '3.10.16 (main, Dec 11 2024, 10:22:29) [Clang 14.0.6 ]', 'platform': 'macOS-15.3.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2025-03-31 17:49:41,910:INFO:estimated required memory for 35380 words and 16 dimensions: 22218640 bytes
# 2025-03-31 17:49:41,910:INFO:resetting layer weights
# 2025-03-31 17:49:41,912:INFO:Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-03-31T17:49:41.912261', 'gensim': '4.3.3', 'python': '3.10.16 (main, Dec 11 2024, 10:22:29) [Clang 14.0.6 ]', 'platform': 'macOS-15.3.1-arm64-arm-64bit', 'event': 'build_vocab'}
# 2025-03-31 17:49:41,912:INFO:Word2Vec lifecycle event {'msg': 'training model with 24 workers on 35380 vocabulary and 16 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2025-03-31T17:49:41.912414', 'gensim': '4.3.3', 'python': '3.10.16 (main, Dec 11 2024, 10:22:29) [Clang 14.0.6 ]', 'platform': 'macOS-15.3.1-arm64-arm-64bit', 'event': 'train'}
# 2025-03-31 17:49:42,291:INFO:EPOCH 0: training on 1630633 raw words (1452625 effective words) took 0.4s, 3952218 effective words/s
# 2025-03-31 17:49:42,688:INFO:EPOCH 1: training on 1630633 raw words (1453059 effective words) took 0.4s, 3728657 effective words/s
# 2025-03-31 17:49:43,091:INFO:EPOCH 2: training on 1630633 raw words (1453012 effective words) took 0.4s, 3688978 effective words/s
# 2025-03-31 17:49:43,542:INFO:EPOCH 3: training on 1630633 raw words (1452535 effective words) took 0.4s, 3282473 effective words/s
# 2025-03-31 17:49:43,985:INFO:EPOCH 4: training on 1630633 raw words (1452627 effective words) took 0.4s, 3348526 effective words/s
# 2025-03-31 17:49:44,397:INFO:EPOCH 5: training on 1630633 raw words (1452855 effective words) took 0.4s, 3594595 effective words/s
# 2025-03-31 17:49:44,791:INFO:EPOCH 6: training on 1630633 raw words (1452321 effective words) took 0.4s, 3761786 effective words/s
# 2025-03-31 17:49:45,184:INFO:EPOCH 7: training on 1630633 raw words (1452979 effective words) took 0.4s, 3783123 effective words/s
# 2025-03-31 17:49:45,564:INFO:EPOCH 8: training on 1630633 raw words (1453040 effective words) took 0.4s, 3907867 effective words/s
# 2025-03-31 17:49:45,943:INFO:EPOCH 9: training on 1630633 raw words (1452465 effective words) took 0.4s, 3915984 effective words/s
# 2025-03-31 17:49:46,317:INFO:EPOCH 10: training on 1630633 raw words (1452427 effective words) took 0.4s, 3953385 effective words/s
# 2025-03-31 17:49:46,697:INFO:EPOCH 11: training on 1630633 raw words (1453254 effective words) took 0.4s, 3904200 effective words/s
# 2025-03-31 17:49:47,096:INFO:EPOCH 12: training on 1630633 raw words (1452565 effective words) took 0.4s, 3709332 effective words/s
# 2025-03-31 17:49:47,469:INFO:EPOCH 13: training on 1630633 raw words (1452507 effective words) took 0.4s, 3984275 effective words/s
# 2025-03-31 17:49:47,848:INFO:EPOCH 14: training on 1630633 raw words (1452372 effective words) took 0.4s, 3919524 effective words/s
# 2025-03-31 17:49:48,232:INFO:EPOCH 15: training on 1630633 raw words (1453137 effective words) took 0.4s, 3858267 effective words/s
# 2025-03-31 17:49:48,606:INFO:EPOCH 16: training on 1630633 raw words (1453124 effective words) took 0.4s, 3977932 effective words/s
# 2025-03-31 17:49:48,983:INFO:EPOCH 17: training on 1630633 raw words (1453369 effective words) took 0.4s, 3942096 effective words/s
# 2025-03-31 17:49:49,369:INFO:EPOCH 18: training on 1630633 raw words (1452797 effective words) took 0.4s, 3838048 effective words/s
# 2025-03-31 17:49:49,749:INFO:EPOCH 19: training on 1630633 raw words (1452847 effective words) took 0.4s, 3901100 effective words/s
# 2025-03-31 17:49:50,138:INFO:EPOCH 20: training on 1630633 raw words (1453149 effective words) took 0.4s, 3815037 effective words/s
# 2025-03-31 17:49:50,512:INFO:EPOCH 21: training on 1630633 raw words (1452346 effective words) took 0.4s, 3957997 effective words/s
# 2025-03-31 17:49:50,890:INFO:EPOCH 22: training on 1630633 raw words (1452928 effective words) took 0.4s, 3936052 effective words/s
# 2025-03-31 17:49:51,272:INFO:EPOCH 23: training on 1630633 raw words (1453047 effective words) took 0.4s, 3883485 effective words/s
# 2025-03-31 17:49:51,646:INFO:EPOCH 24: training on 1630633 raw words (1453079 effective words) took 0.4s, 3977670 effective words/s
# 2025-03-31 17:49:52,023:INFO:EPOCH 25: training on 1630633 raw words (1453430 effective words) took 0.4s, 3944325 effective words/s
# 2025-03-31 17:49:52,406:INFO:EPOCH 26: training on 1630633 raw words (1452567 effective words) took 0.4s, 3869386 effective words/s
# 2025-03-31 17:49:52,783:INFO:EPOCH 27: training on 1630633 raw words (1453066 effective words) took 0.4s, 3932556 effective words/s
# 2025-03-31 17:49:53,163:INFO:EPOCH 28: training on 1630633 raw words (1453145 effective words) took 0.4s, 3912895 effective words/s
# 2025-03-31 17:49:53,544:INFO:EPOCH 29: training on 1630633 raw words (1452464 effective words) took 0.4s, 3893907 effective words/s
# 2025-03-31 17:49:53,919:INFO:EPOCH 30: training on 1630633 raw words (1452951 effective words) took 0.4s, 3951158 effective words/s
# 2025-03-31 17:49:54,296:INFO:EPOCH 31: training on 1630633 raw words (1452539 effective words) took 0.4s, 3937548 effective words/s
# 2025-03-31 17:49:54,674:INFO:EPOCH 32: training on 1630633 raw words (1452677 effective words) took 0.4s, 3928731 effective words/s
# 2025-03-31 17:49:55,051:INFO:EPOCH 33: training on 1630633 raw words (1453245 effective words) took 0.4s, 3929454 effective words/s
# 2025-03-31 17:49:55,429:INFO:EPOCH 34: training on 1630633 raw words (1452488 effective words) took 0.4s, 3925968 effective words/s
# 2025-03-31 17:49:55,807:INFO:EPOCH 35: training on 1630633 raw words (1452458 effective words) took 0.4s, 3918648 effective words/s
# 2025-03-31 17:49:56,182:INFO:EPOCH 36: training on 1630633 raw words (1452867 effective words) took 0.4s, 3969868 effective words/s
# 2025-03-31 17:49:56,567:INFO:EPOCH 37: training on 1630633 raw words (1452942 effective words) took 0.4s, 3851045 effective words/s
# 2025-03-31 17:49:56,944:INFO:EPOCH 38: training on 1630633 raw words (1453311 effective words) took 0.4s, 3944696 effective words/s
# 2025-03-31 17:49:57,318:INFO:EPOCH 39: training on 1630633 raw words (1453074 effective words) took 0.4s, 3963139 effective words/s
# 2025-03-31 17:49:57,698:INFO:EPOCH 40: training on 1630633 raw words (1453146 effective words) took 0.4s, 3917090 effective words/s
# 2025-03-31 17:49:58,073:INFO:EPOCH 41: training on 1630633 raw words (1452766 effective words) took 0.4s, 3945446 effective words/s
# 2025-03-31 17:49:58,452:INFO:EPOCH 42: training on 1630633 raw words (1452927 effective words) took 0.4s, 3913421 effective words/s
# 2025-03-31 17:49:58,836:INFO:EPOCH 43: training on 1630633 raw words (1452333 effective words) took 0.4s, 3860208 effective words/s
# 2025-03-31 17:49:59,207:INFO:EPOCH 44: training on 1630633 raw words (1453029 effective words) took 0.4s, 3994666 effective words/s
# 2025-03-31 17:49:59,590:INFO:EPOCH 45: training on 1630633 raw words (1453144 effective words) took 0.4s, 3873842 effective words/s
# 2025-03-31 17:49:59,968:INFO:EPOCH 46: training on 1630633 raw words (1452885 effective words) took 0.4s, 3924846 effective words/s
# 2025-03-31 17:50:00,342:INFO:EPOCH 47: training on 1630633 raw words (1452632 effective words) took 0.4s, 3973236 effective words/s
# 2025-03-31 17:50:00,729:INFO:EPOCH 48: training on 1630633 raw words (1452660 effective words) took 0.4s, 3835595 effective words/s
# 2025-03-31 17:50:01,102:INFO:EPOCH 49: training on 1630633 raw words (1452835 effective words) took 0.4s, 3969075 effective words/s
# 2025-03-31 17:50:01,103:INFO:Word2Vec lifecycle event {'msg': 'training on 81531650 raw words (72642047 effective words) took 19.2s, 3785182 effective words/s', 'datetime': '2025-03-31T17:50:01.103235', 'gensim': '4.3.3', 'python': '3.10.16 (main, Dec 11 2024, 10:22:29) [Clang 14.0.6 ]', 'platform': 'macOS-15.3.1-arm64-arm-64bit', 'event': 'train'}
# 2025-03-31 17:50:01,103:INFO:Word2Vec lifecycle event {'params': 'Word2Vec<vocab=35380, vector_size=16, alpha=0.025>', 'datetime': '2025-03-31T17:50:01.103434', 'gensim': '4.3.3', 'python': '3.10.16 (main, Dec 11 2024, 10:22:29) [Clang 14.0.6 ]', 'platform': 'macOS-15.3.1-arm64-arm-64bit', 'event': 'created'}

# %%
# 随机选择5个用户，查看这些用户前后查看文章的相似性
sub_user_ids = np.random.choice(user_click_merge.user_id.unique(), size=15, replace=False)
sub_user_info = user_click_merge[user_click_merge['user_id'].isin(sub_user_ids)]

sub_user_info.head()
# Out:
#         user_id  click_article_id  click_timestamp  click_environment  \
# 10895    245556            162655         0.000831                  4
# 10896    245556            158536         0.000839                  4
# 76129    221642            160417         0.006300                  2
# 76130    221642            162655         0.006308                  2
# 137850   200101            363173         0.019431                  4
#
#         click_deviceGroup  click_os  click_country  click_region  \
# 10895                   1        17              1            21
# 10896                   1        17              1            21
# 76129                   3        20              1            13
# 76130                   3        20              1            13
# 137850                  1        17              1             9
#
#         click_referrer_type  rank  click_cnts  category_id  created_at_ts  \
# 10895                     1    27          27          281       0.989199
# 10896                     1    26          27          281       0.989112
# 76129                     2    11          11          281       0.989178
# 76130                     2    10          11          281       0.989199
# 137850                    1    16          16          455       0.989196
#
#         words_count
# 10895           245
# 10896           858
# 76129           173
# 76130           245
# 137850          168

# %%
# 上一个版本，这个函数使用的是赛题提供的词向量，但是由于给出的embedding并不是所有的数据的embedding，所以运行下面画图函数的时候会报keyerror的错误
# 为了防止出现这个错误，这里修改为使用word2vec训练得到的词向量进行可视化
def get_item_sim_list(df):
    sim_list = []
    item_list = df['click_article_id'].values
    for i in range(0, len(item_list)-1):
        emb1 = item_w2v_emb_dict[str(item_list[i])] # 需要注意的是word2vec训练时候使用的是str类型的数据
        emb2 = item_w2v_emb_dict[str(item_list[i+1])]
        sim_list.append(np.dot(emb1,emb2)/(np.linalg.norm(emb1)*(np.linalg.norm(emb2))))
    sim_list.append(0)
    return sim_list

# %%
for _, user_df in sub_user_info.groupby('user_id'):
    item_sim_list = get_item_sim_list(user_df)
    plt.plot(item_sim_list)
